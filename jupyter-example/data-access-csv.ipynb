# %% [markdown]
# # OxCOVID19 (https://covid19.eng.ox.ac.uk/) - CSV data access
#
#
# This notebook demonstrates how to access OxCovid19 CSV data.

# %%
import pandas as pd

# %% [markdown]
#  ## EPIDEMIOLOGY table

# %% [markdown]
# ### List of available sources

# %%
from bs4 import BeautifulSoup
import requests

url = 'https://github.com/covid19db/data/tree/master/data-epidemiology/'
expr = re.compile(r'.*epidemiology-(.*)\.csv')

page = requests.get(url).text
soup = BeautifulSoup(page, 'html.parser')
sources = [expr.sub(r'\1', node.get('href')) for node in soup.find_all('a') if node.get('href').endswith('.csv')]

print(sources)
# Out:
# ['AUS_C1A', 'BEL_WY', 'BRA_MSHM', 'CAN_GOV', 'CHE_OPGOV', 'DEU_JPGG', 'ESP_MSVP', 'EU_ZH', 'FRA_SPFCG', 'GBR_PHE', 'GBR_PHTW', 'GBR_PHW', 'IDN_GTPPC', 'IND_COVIND', 'ITA_PC', 'ITA_PCDM', 'JPN_C1JACD', 'KOR_DS4C', 'LAT_DSRP', 'MYS_MHYS', 'NGA_CDC', 'NGA_SO', 'NLD_CW', 'NLD_WY', 'PAK_GOV', 'POL_WIKI', 'PRT_MSDS', 'RUS_GOV', 'SWE_GM', 'SWE_SIR', 'THA_STAT', 'TUR_MHOE', 'USA_CTP', 'USA_NYT', 'WRD_ECDC', 'WRD_WHOJHU', 'ZAF_DSFSI']

# %% [markdown]
# ### Data for single source

# %%
source = "GBR_PHTW"

url = f"https://raw.githubusercontent.com/covid19db/data/master/data-epidemiology/covid19db-epidemiology-{source}.csv"
df_epidemiology = pd.read_csv(url)
df_epidemiology.head()
# Out:
#      source        date         country countrycode adm_area_1 adm_area_2  \
# 0  GBR_PHTW  08-01-2020  United Kingdom         GBR      Wales        NaN
# 1  GBR_PHTW  09-01-2020  United Kingdom         GBR      Wales        NaN
# 2  GBR_PHTW  10-01-2020  United Kingdom         GBR      Wales        NaN
# 3  GBR_PHTW  11-01-2020  United Kingdom         GBR      Wales        NaN
# 4  GBR_PHTW  12-01-2020  United Kingdom         GBR      Wales        NaN
#
#    adm_area_3  tested  confirmed  recovered  dead  hospitalised  \
# 0         NaN     1.0        0.0        NaN   NaN           NaN
# 1         NaN     1.0        0.0        NaN   NaN           NaN
# 2         NaN     1.0        0.0        NaN   NaN           NaN
# 3         NaN     1.0        0.0        NaN   NaN           NaN
# 4         NaN     1.0        0.0        NaN   NaN           NaN
#
#    hospitalised_icu  quarantined          gid
# 0               NaN          NaN  ['GBR.4_1']
# 1               NaN          NaN  ['GBR.4_1']
# 2               NaN          NaN  ['GBR.4_1']
# 3               NaN          NaN  ['GBR.4_1']
# 4               NaN          NaN  ['GBR.4_1']

# %% [markdown]
# ## MOBILITY table

# %%
source = "GOOGLE_MOBILITY"
countrycode = "GBR"
    
url = f"https://raw.githubusercontent.com/covid19db/data/master/data-mobility/covid19db-mobility-{source}.csv"
df_mobility = pd.read_csv(url)
df_mobility = df_mobility[df_mobility.countrycode==countrycode]
df_mobility.head()
# Out:
#                source        date         country countrycode adm_area_1  \
# 1574  GOOGLE_MOBILITY  15-02-2020  United Kingdom         GBR        NaN
# 1575  GOOGLE_MOBILITY  15-02-2020  United Kingdom         GBR          %
# 1576  GOOGLE_MOBILITY  15-02-2020  United Kingdom         GBR          %
# 1577  GOOGLE_MOBILITY  15-02-2020  United Kingdom         GBR          %
# 1578  GOOGLE_MOBILITY  15-02-2020  United Kingdom         GBR          %
#
#            adm_area_2  adm_area_3  transit_stations  residential  workplace  \
# 1574              NaN         NaN             -12.0          2.0       -4.0
# 1575       Merseyside         NaN              -8.0          2.0       -3.0
# 1576  South Yorkshire         NaN             -11.0          2.0       -2.0
# 1577    Tyne and Wear         NaN              -9.0          2.0       -2.0
# 1578    West Midlands         NaN             -11.0          2.0       -4.0
#
#       parks  retail_recreation  grocery_pharmacy  \
# 1574  -35.0              -12.0               2.0
# 1575  -33.0              -10.0               2.0
# 1576  -41.0               -7.0               2.0
# 1577  -27.0              -10.0               2.0
# 1578  -32.0              -10.0               2.0
#
#                                                     gid  transit  walking  \
# 1574                                            ['GBR']      NaN      NaN
# 1575  ['GBR.1.47_1', 'GBR.1.79_1', 'GBR.1.82_1', 'GB...      NaN      NaN
# 1576  ['GBR.1.1_1', 'GBR.1.27_1', 'GBR.1.77_1', 'GBR...      NaN      NaN
# 1577  ['GBR.1.34_1', 'GBR.1.58_1', 'GBR.1.62_1', 'GB...      NaN      NaN
# 1578  ['GBR.1.4_1', 'GBR.1.21_1', 'GBR.1.29_1', 'GBR...      NaN      NaN
#
#       driving
# 1574      NaN
# 1575      NaN
# 1576      NaN
# 1577      NaN
# 1578      NaN

# %% [markdown]
# ## GOVERNMENT_REPONSE table

# %%
countrycode = "GBR"

url = f"https://raw.githubusercontent.com/covid19db/data/master/data-government-response/covid19db-government-response-GOVTRACK.csv"
df_govtrack = pd.read_csv(url)
df_govtrack = df_govtrack[df_govtrack.countrycode==countrycode]
df_govtrack.head()
# Out:
#        source        date  gid         country countrycode  adm_area_1  \
# 165  GOVTRACK  01-01-2020  GBR  United Kingdom         GBR         NaN
# 340  GOVTRACK  02-01-2020  GBR  United Kingdom         GBR         NaN
# 515  GOVTRACK  03-01-2020  GBR  United Kingdom         GBR         NaN
# 690  GOVTRACK  04-01-2020  GBR  United Kingdom         GBR         NaN
# 865  GOVTRACK  05-01-2020  GBR  United Kingdom         GBR         NaN
#
#      adm_area_2  adm_area_3  c1_school_closing  c1_flag  ...  \
# 165         NaN         NaN                0.0      NaN  ...
# 340         NaN         NaN                0.0      NaN  ...
# 515         NaN         NaN                0.0      NaN  ...
# 690         NaN         NaN                0.0      NaN  ...
# 865         NaN         NaN                0.0      NaN  ...
#
#      stringency_index  stringency_indexfordisplay  stringency_legacy_index  \
# 165               0.0                         0.0                      0.0
# 340               0.0                         0.0                      0.0
# 515               0.0                         0.0                      0.0
# 690               0.0                         0.0                      0.0
# 865               0.0                         0.0                      0.0
#
#      stringency_legacy_indexfordisplay  government_response_index  \
# 165                                0.0                        0.0
# 340                                0.0                        0.0
# 515                                0.0                        0.0
# 690                                0.0                        0.0
# 865                                0.0                        0.0
#
#      government_response_index_for_display  containment_health_index  \
# 165                                    0.0                       0.0
# 340                                    0.0                       0.0
# 515                                    0.0                       0.0
# 690                                    0.0                       0.0
# 865                                    0.0                       0.0
#
#      containment_health_index_for_display  economic_support_index  \
# 165                                   0.0                     0.0
# 340                                   0.0                     0.0
# 515                                   0.0                     0.0
# 690                                   0.0                     0.0
# 865                                   0.0                     0.0
#
#      economic_support_index_for_display
# 165                                 0.0
# 340                                 0.0
# 515                                 0.0
# 690                                 0.0
# 865                                 0.0
#
# [5 rows x 45 columns]

# %% [markdown]
# ## BASELINE MORTALITY table

# %%
countrycode = "GBR"

url = f"https://raw.githubusercontent.com/covid19db/data/master/data-statistics/covid19db-baseline-mortality.csv"
baseline_mortality = pd.read_csv(url)
baseline_mortality = baseline_mortality[baseline_mortality.countrycode==countrycode]
baseline_mortality.head()
# Out:
#     source        date         country countrycode adm_level      gid  deaths
# 492     UN  01-01-1982  United Kingdom         GBR       NaN  ['GBR']   69894
# 524     UN  01-02-1982  United Kingdom         GBR       NaN  ['GBR']   56309
# 545     UN  01-03-1982  United Kingdom         GBR       NaN  ['GBR']   63030
# 567     UN  01-04-1982  United Kingdom         GBR       NaN  ['GBR']   56899
# 594     UN  01-05-1982  United Kingdom         GBR       NaN  ['GBR']   54068

# %% [markdown]
# ## COUNTRY STATISTICS table

# %%
countrycode = "GBR"

url = f"https://raw.githubusercontent.com/covid19db/data/master/data-statistics/covid19db-country-statistics.csv"
df_stats = pd.read_csv(url)
df_stats = df_stats[df_stats.countrycode==countrycode]
df_stats.head()
# Out:
#     source       year                                            country  \
# 203     WB       2020                                     United Kingdom
# 228    EVS  1981-1984  United Kingdom of Great Britain and Northern I...
# 256    EVS  1990-1993  United Kingdom of Great Britain and Northern I...
# 289    EVS  1999-2001  United Kingdom of Great Britain and Northern I...
# 332    EVS  2008-2010  United Kingdom of Great Britain and Northern I...
#
#     countrycode  adm_level      gid  samplesize  \
# 203         GBR          0  ['GBR']          -1
# 228         GBR          0  ['GBR']        1167
# 256         GBR          0  ['GBR']        1484
# 289         GBR          0  ['GBR']        1000
# 332         GBR          0  ['GBR']        1561
#
#                                             properties
# 203  {'EN.POP.DNST': {'Year': 2018.0, 'Indicator Na...
# 228  {'A001': {'Label': 'Important in life: Family'...
# 256  {'A001': {'Label': 'Important in life: Family'...
# 289  {'A001': {'Label': 'Important in life: Family'...
# 332  {'A001': {'Label': 'Important in life: Family'...
