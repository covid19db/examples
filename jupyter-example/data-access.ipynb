# %% [markdown]
# # OxCOVID19 (https://covid19.eng.ox.ac.uk/) - Database access
#
#
# This notebook demonstrates how to access OxCovid19 Database.

# %%
import psycopg2
import pandas as pd

conn = psycopg2.connect(
    host='covid19db.org',
    port=5432,
    dbname='covid19',
    user='covid19',
    password='covid19')
cur = conn.cursor()

# %% [markdown]
#  ## EPIDEMIOLOGY table

# %% [markdown]
# ### List of available sources

# %%
sql_command = """SELECT DISTINCT source FROM epidemiology ORDER by source"""
df_epidemiology = pd.read_sql(sql_command, conn)
df_epidemiology.values.flatten()
# Out:
# array(['AUS_C1A', 'BEL_WY', 'BRA_MSHM', 'CAN_GOV', 'CHE_OPGOV',
#        'DEU_JPGG', 'ESP_MSVP', 'EU_ZH', 'FRA_SPFCG', 'GBR_PHE',
#        'GBR_PHTW', 'GBR_PHW', 'IDN_GTPPC', 'IND_COVIND', 'ITA_PC',
#        'ITA_PCDM', 'JPN_C1JACD', 'KOR_DS4C', 'LAT_DSRP', 'MYS_MHYS',
#        'NGA_CDC', 'NGA_SO', 'NLD_CW', 'NLD_WY', 'PAK_GOV', 'POL_WIKI',
#        'PRT_MSDS', 'RUS_GOV', 'SWE_GM', 'SWE_SIR', 'THA_STAT', 'TUR_MHOE',
#        'USA_CTP', 'USA_NYT', 'WRD_ECDC', 'ZAF_DSFSI'], dtype=object)

# %% [markdown]
# ### Data for single source

# %%
source = "GBR_PHTW"

sql_command = """SELECT * FROM epidemiology WHERE source = %(source)s ORDER by date DESC"""
df_epidemiology = pd.read_sql(sql_command, conn, params={'source': source})
df_epidemiology.head()
# Out:
#      source        date         country countrycode adm_area_1  \
# 0  GBR_PHTW  2020-06-11  United Kingdom         GBR   Scotland
# 1  GBR_PHTW  2020-06-11  United Kingdom         GBR   Scotland
# 2  GBR_PHTW  2020-06-11  United Kingdom         GBR   Scotland
# 3  GBR_PHTW  2020-06-11  United Kingdom         GBR   Scotland
# 4  GBR_PHTW  2020-06-11  United Kingdom         GBR   Scotland
#
#                       adm_area_2 adm_area_3  tested  confirmed recovered  \
# 0                    NHS Tayside       None     NaN     1685.0      None
# 1                   NHS Highland       None     NaN      341.0      None
# 2  NHS Greater Glasgow and Clyde       None     NaN     3995.0      None
# 3                   NHS Grampian       None     NaN     1288.0      None
# 4               NHS Forth Valley       None     NaN      948.0      None
#
#    dead hospitalised hospitalised_icu quarantined  \
# 0   NaN         None             None        None
# 1   NaN         None             None        None
# 2   NaN         None             None        None
# 3   NaN         None             None        None
# 4   NaN         None             None        None
#
#                                                  gid
# 0                 [GBR.3.3_1, GBR.3.7_1, GBR.3.24_1]
# 1                            [GBR.3.4_1, GBR.3.17_1]
# 2  [GBR.3.9_1, GBR.3.11_1, GBR.3.16_1, GBR.3.18_1...
# 3                 [GBR.3.1_1, GBR.3.2_1, GBR.3.20_1]
# 4                [GBR.3.5_1, GBR.3.14_1, GBR.3.30_1]

# %% [markdown]
# ## MOBILITY table

# %%
source = "GOOGLE_MOBILITY"
countrycode = "GBR"

sql_command = """SELECT * FROM mobility WHERE source=%(source)s AND countrycode=%(countrycode)s ORDER by date DESC"""
df_mobility = pd.read_sql(sql_command, conn, params={'source': source, 'countrycode': countrycode})
df_mobility.head()
# Out:
#             source        date         country countrycode adm_area_1  \
# 0  GOOGLE_MOBILITY  2020-06-07  United Kingdom         GBR      Wales
# 1  GOOGLE_MOBILITY  2020-06-07  United Kingdom         GBR      Wales
# 2  GOOGLE_MOBILITY  2020-06-07  United Kingdom         GBR    England
# 3  GOOGLE_MOBILITY  2020-06-07  United Kingdom         GBR    England
# 4  GOOGLE_MOBILITY  2020-06-07  United Kingdom         GBR    England
#
#          adm_area_2 adm_area_3  transit_stations  residential  workplace  \
# 0      Denbighshire       None             -38.0          NaN      -26.0
# 1          Bridgend       None             -48.0          NaN      -17.0
# 2        Derbyshire       None             -34.0         10.0      -27.0
# 3  Bracknell Forest       None             -29.0          NaN      -30.0
# 4   Nottinghamshire       None             -35.0         10.0      -28.0
#
#    parks  retail_recreation  grocery_pharmacy           gid transit walking  \
# 0  -13.0              -62.0               NaN   [GBR.4.9_1]    None    None
# 1   40.0              -70.0               NaN   [GBR.4.3_1]    None    None
# 2   12.0              -71.0              10.0  [GBR.1.25_1]    None    None
# 3   65.0              -70.0               NaN   [GBR.1.9_1]    None    None
# 4  -15.0              -69.0              10.0  [GBR.1.67_1]    None    None
#
#   driving
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %% [markdown]
# ## GOVERNMENT_REPONSE table

# %%
countrycode = "GBR"

sql_command = """SELECT * FROM government_response WHERE countrycode=%(countrycode)s ORDER by date DESC"""
df_govtrack = pd.read_sql(sql_command, conn, params={'countrycode': countrycode})
df_govtrack.head()
# Out:
#      source        date  gid         country countrycode adm_area_1  \
# 0  GOVTRACK  2020-06-11  GBR  United Kingdom         GBR       None
# 1  GOVTRACK  2020-06-10  GBR  United Kingdom         GBR       None
# 2  GOVTRACK  2020-06-09  GBR  United Kingdom         GBR       None
# 3  GOVTRACK  2020-06-08  GBR  United Kingdom         GBR       None
# 4  GOVTRACK  2020-06-07  GBR  United Kingdom         GBR       None
#
#   adm_area_2 adm_area_3  c1_school_closing  c1_flag  ...  \
# 0       None       None                  3      0.0  ...
# 1       None       None                  3      0.0  ...
# 2       None       None                  3      0.0  ...
# 3       None       None                  3      0.0  ...
# 4       None       None                  3      0.0  ...
#
#    stringency_indexfordisplay  stringency_legacy_index  \
# 0                       70.37                    76.19
# 1                       70.37                    76.19
# 2                       70.37                    76.19
# 3                       70.37                    76.19
# 4                       64.81                    69.05
#
#    stringency_legacy_indexfordisplay  government_response_index  \
# 0                              76.19                      70.51
# 1                              76.19                      70.51
# 2                              76.19                      70.51
# 3                              76.19                      70.51
# 4                              69.05                      66.67
#
#    government_response_index_for_display  containment_health_index  \
# 0                                  70.51                     65.15
# 1                                  70.51                     65.15
# 2                                  70.51                     65.15
# 3                                  70.51                     65.15
# 4                                  66.67                     60.61
#
#    containment_health_index_for_display  economic_support_index  \
# 0                                 65.15                   100.0
# 1                                 65.15                   100.0
# 2                                 65.15                   100.0
# 3                                 65.15                   100.0
# 4                                 60.61                   100.0
#
#    economic_support_index_for_display  \
# 0                               100.0
# 1                               100.0
# 2                               100.0
# 3                               100.0
# 4                               100.0
#
#                                              actions
# 0  {'policyActions': [{'notes': None, 'flagged': ...
# 1  {'policyActions': [{'notes': None, 'flagged': ...
# 2  {'policyActions': [{'notes': None, 'flagged': ...
# 3  {'policyActions': [{'notes': None, 'flagged': ...
# 4  {'policyActions': [{'notes': None, 'flagged': ...
#
# [5 rows x 46 columns]

# %% [markdown]
# ## COUNTRY STATISTICS table

# %%
countrycode = "GBR"

sql_command = """SELECT * FROM country_statistics WHERE countrycode=%(countrycode)s"""
df_stats = pd.read_sql(sql_command, conn, params={'countrycode': countrycode})
df_stats.head()
# Out:
#   source       year                                            country  \
# 0     WB       2020                                     United Kingdom
# 1    EVS  1981-1984  United Kingdom of Great Britain and Northern I...
# 2    EVS  1990-1993  United Kingdom of Great Britain and Northern I...
# 3    EVS  1999-2001  United Kingdom of Great Britain and Northern I...
# 4    EVS  2008-2010  United Kingdom of Great Britain and Northern I...
#
#   countrycode adm_level    gid  samplesize  \
# 0         GBR         0  [GBR]          -1
# 1         GBR         0  [GBR]        1167
# 2         GBR         0  [GBR]        1484
# 3         GBR         0  [GBR]        1000
# 4         GBR         0  [GBR]        1561
#
#                                           properties
# 0  {'EN.POP.DNST': {'Year': 2018.0, 'Indicator Na...
# 1  {'A001': {'Label': 'Important in life: Family'...
# 2  {'A001': {'Label': 'Important in life: Family'...
# 3  {'A001': {'Label': 'Important in life: Family'...
# 4  {'A001': {'Label': 'Important in life: Family'...

# %% [markdown]
# ## WEATHER table

# %%
countrycode = "GBR"

sql_command = """SELECT * FROM weather WHERE countrycode=%(countrycode)s ORDER by date DESC"""
df_weather = pd.read_sql(sql_command, conn, params={'countrycode': countrycode})
df_weather.head()
# Out:
#          date countrycode        gid  precip_max_avg  precip_max_std  \
# 0  2020-06-10         GBR  GBR.4.9_1        0.000567        0.000207
# 1  2020-06-10         GBR  GBR.4.8_1        0.000738        0.000318
# 2  2020-06-10         GBR  GBR.4.7_1        0.001628        0.000772
# 3  2020-06-10         GBR  GBR.4.6_1        0.001518        0.000371
# 4  2020-06-10         GBR  GBR.4.5_1        0.001284        0.000132
#
#    precip_mean_avg  precip_mean_std  specific_humidity_max_avg  \
# 0         0.000093         0.000022                   0.007731
# 1         0.000123         0.000030                   0.007790
# 2         0.000322         0.000068                   0.008378
# 3         0.000285         0.000062                   0.008616
# 4         0.000183         0.000016                   0.008423
#
#    specific_humidity_max_std  specific_humidity_mean_avg  ...  \
# 0                   0.000199                    0.007280  ...
# 1                   0.000126                    0.007243  ...
# 2                   0.000263                    0.007576  ...
# 3                   0.000249                    0.007652  ...
# 4                   0.000122                    0.007446  ...
#
#    windgust_mean_avg  windgust_mean_std  windgust_min_avg  windgust_min_std  \
# 0           5.005787           0.129068          1.152778          0.326906
# 1           4.787879           0.414353          1.534091          0.617203
# 2           5.534540           0.493433          2.111842          0.534800
# 3           5.766927           0.466796          1.125000          0.434514
# 4           6.153646           0.096354          3.937500          0.187500
#
#    windspeed_max_avg  windspeed_max_std  windspeed_mean_avg  \
# 0           5.930555           0.441396            2.218750
# 1           4.795455           0.506415            2.080019
# 2           5.855263           0.399965            2.760143
# 3           5.526042           0.797113            2.855903
# 4           5.375000           0.500000            3.031250
#
#    windspeed_mean_std  windspeed_min_avg  windspeed_min_std
# 0            0.100665           0.652778           0.241363
# 1            0.198828           0.465909           0.282496
# 2            0.307166           1.006579           0.279431
# 3            0.319205           0.531250           0.237308
# 4            0.026042           1.562500           0.312500
#
# [5 rows x 35 columns]

# %% [markdown]
# ## ADMINISTRATIVE_DIVISION table

# %%
import geopandas as gpd

countrycode = "GBR"
levels_list=(0,1,2)

sql_command = f"SELECT * FROM administrative_division WHERE adm_level IN %(levels_list)s AND countrycode=%(countrycode)s"   
df_admin = gpd.GeoDataFrame.from_postgis(
    sql_command, 
    conn, 
    params={'countrycode': countrycode, 'levels_list': levels_list}, 
    geom_col='geometry')
df_admin.head()
# Out:
#           country countrycode countrycode_alpha2  adm_level adm_area_1  \
# 0  United Kingdom         GBR                 GB          0       None
# 1  United Kingdom         GBR                 GB          1    England
# 2  United Kingdom         GBR                 GB          2    England
# 3  United Kingdom         GBR                 GB          2    England
# 4  United Kingdom         GBR                 GB          2    England
#
#   adm_area_1_code                    adm_area_2 adm_area_2_code adm_area_3  \
# 0            None                          None            None       None
# 1         GBR.1_1                          None            None       None
# 2         GBR.1_1                      Barnsley       GBR.1.1_1       None
# 3         GBR.1_1  Bath and North East Somerset       GBR.1.2_1       None
# 4         GBR.1_1                  Bedfordshire       GBR.1.3_1       None
#
#   adm_area_3_code        gid   latitude  longitude  \
# 0            None        GBR  54.164734  -2.895751
# 1            None    GBR.1_1  52.589902  -1.461575
# 2            None  GBR.1.1_1  53.526238  -1.533560
# 3            None  GBR.1.2_1  51.355271  -2.469959
# 4            None  GBR.1.3_1  52.195932  -0.489157
#
#                                           properties  \
# 0       {'GID_0': 'GBR', 'NAME_0': 'United Kingdom'}
# 1  {'CC_1': None, 'GID_0': 'GBR', 'GID_1': 'GBR.1...
# 2  {'CC_2': None, 'GID_0': 'GBR', 'GID_1': 'GBR.1...
# 3  {'CC_2': None, 'GID_0': 'GBR', 'GID_1': 'GBR.1...
# 4  {'CC_2': None, 'GID_0': 'GBR', 'GID_1': 'GBR.1...
#
#                                             geometry
# 0  MULTIPOLYGON (((-5.86721 56.65690, -5.74694 56...
# 1  MULTIPOLYGON (((-4.63632 50.35447, -4.63361 50...
# 2  POLYGON ((-1.78997 53.47293, -1.81611 53.51611...
# 3  POLYGON ((-2.68629 51.31516, -2.68066 51.32836...
# 4  POLYGON ((-0.58508 52.11364, -0.63161 52.14651...
